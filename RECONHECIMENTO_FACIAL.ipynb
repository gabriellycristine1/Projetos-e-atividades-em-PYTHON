# %% [markdown]
# <a href="https://colab.research.google.com/github/gabriellycristine1/Projetos_e_Atividades_Python/blob/main/RECONHECIMENTO_FACIAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from PIL import Image

# %%
import zipfile
path = '/content/yalefaces.zip'
zip_object = zipfile.ZipFile(file=path, mode='r')
zip_object.extractall('./')
zip_object.close()

# %%
from google.colab.patches import cv2_imshow

# %%
import os
os.listdir('/content/yalefaces/train')

# %%
def dados_imagem():
  caminhos = [os.path.join('/content/yalefaces/train', f) for f in os.listdir('/content/yalefaces/train')]
  faces = []
  ids = []
  for caminho in caminhos:

    if caminho == '/content/yalefaces/treinamento/.ipynb_checkpoints':
      continue
      
    imagem = Image.open(caminho).convert('L')
    imagem_np = np.array(imagem, 'uint8')
    id = int(os.path.split(caminho)[1].split('.')[0].replace('subject', '')) 
    ids.append(id)
    faces.append(imagem_np)

  return np.array(ids), faces

# %%
ids, faces = dados_imagem()

# %%
lbph = cv2.face.
()
lbph.train(faces, ids)
lbph.write('classificadorLBPH.yml')

# %%
reconhecer = cv2.face.LBPHFaceRecognizer_create()
reconhecer.read('/content/classificadorLBPH.yml')

# %%
image_test = '/content/yalefaces/test/subject01.gif'

# %%
imagem = Image.open(image_test).convert("L")
image_np = np.array(imagem,'uint8')
print(image_np)
# Out:
# [[130 130 130 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [ 68  68  68 ...  68  68  68]]

# %%
cv2_imshow(faces[0])
# Out:
# <PIL.Image.Image image mode=L size=320x243 at 0x7EFC35331790>

# %%
idprevisto = reconhecer.predict(image_np)
print(idprevisto)
# Out:
# (1, 22.62525404335563)

# %%
idcorreto = int(os.path.split(image_test)[1].split('.')[0].replace('subject',''))
idcorreto
# Out:
# 1

# %%
cv2.putText(image_np, 'Previsto: ' + str(idprevisto),(x,y+30))
cv2.putText(image_np, 'Correto: ' + str(idcorreto),)
cv2_imshow(image_np)
